# %% [markdown]
# # Convolutional Neural Networks
#
# The standard neural network we looked at in the previous lesson takes in a vector as input thus a flattened image could be passed in as input and used for classification problems successfully. But this is not the best way to do it. If you think about an image, the spatial relations between the different pixels is an important piece of information when determening what the image is. If we scrambled the pixels of an image, it would be much harder to determine what is in it. This is basically what we are doing when we flatten the image and use standard NNs as the order of pixels which we use in the input vector to the network does not affect the performance of the NN. We are losing the information of the spatial relations of the pixels.
#
# Convolutional neural networks solve this very problem. Rather than performing a matrix multiplication, a convolution operation is performed which can take in a 2d input and give a 2d output hence keep the information about the spatial relations of the pixels. This greatly increases their performance on image and video processing tasks.
#
# In the convolution proccess, you have a filter which you start on the top left side of the image and slide across the whole image, taking a dot product between the values of the filter and pixel values of the image. Bear in mind that colour images have three channels so your filter may be 3-d so you take the dot product across a 3d-volume. Each dot product corresponds to a single activation value in a 2-d matrix of neurons which corresponds to a single layer in the output.
#
# The animation below shows how a 1x3x3 filter is applied to a 1x5x5 image. Notice how the filter has high output values when there is an X shape in the input image. This is because the values of the filter are such that it is performing pattern matching for the X shape.
#
# ![](cnn.gif)
#
# For a long time, operations like this were used in computer vision to find different patterns in images with the engineers having to manually tune the values of the filters to perform the required function. The only difference now is that we apply an activation such as Relu or Sigmoid at each layer and after setting up the structure of the network, we initialize the filter values randomly before using gradient descent to automatically tune the values of the filters.
# We can also apply pooling operations to subsample the output at each layer therefore reducing the number of parameters that need to be learned for the next convolution operation.
#
# ![](cnn.png)
#
# Just like before, each layer in the whole network learns higher level abstract features from the inputs. In CNNs the features are even more interpretable as the output of each layer is 2d so can be viewed as an image.
#
# ## Implementation
# we will be implementing a CNN which can take as input a 1x28x28 black and white images of hand-written digits and classifying it into which digit the image depicts. We have a dataset of 60,000 images and their corresponding labels to train on and 10,000 to test on. This is called the MNIST dataset.

# %% [markdown]
# Lets import the necessary libraries

# %%
# %matplotlib notebook
import torch
import torchvision
from torchvision import transforms, datasets
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %% [markdown]
# Import the MNIST training and test sets from the default PyTorch datasets

# %%
training_data = # get the MNIST training dataset from torchvision datasets (set train=True, download=True and shuffle the dataset)

test_data = # get the MNIST testing dataset from torchvision datasets

#show our first training data item
#print(training_data[0])
plt.imshow(training_data[0][0][0], cmap='gray_r')
plt.show()

print('Number of training examples:', len(training_data))
print('Number of test examples:', len(test_data))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0706, 0.0706, 0.0706,
#           0.4941, 0.5333, 0.6863, 0.1020, 0.6510, 1.0000, 0.9686, 0.4980,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1176, 0.1412, 0.3686, 0.6039, 0.6667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.8824, 0.6745, 0.9922, 0.9490, 0.7647, 0.2510,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1922,
#           0.9333, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9843, 0.3647, 0.3216, 0.3216, 0.2196, 0.1529, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765, 0.7137,
#           0.9686, 0.9451, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3137, 0.6118, 0.4196, 0.9922, 0.9922, 0.8039, 0.0431, 0.0000,
#           0.1686, 0.6039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0549, 0.0039, 0.6039, 0.9922, 0.3529, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.5451, 0.9922, 0.7451, 0.0078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0431, 0.7451, 0.9922, 0.2745, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1373, 0.9451, 0.8824, 0.6275,
#           0.4235, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3176, 0.9412, 0.9922,
#           0.9922, 0.4667, 0.0980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1765, 0.7294,
#           0.9922, 0.9922, 0.5882, 0.1059, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0627,
#           0.3647, 0.9882, 0.9922, 0.7333, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.9765, 0.9922, 0.9765, 0.2510, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1804, 0.5098,
#           0.7176, 0.9922, 0.9922, 0.8118, 0.0078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1529, 0.5804, 0.8980, 0.9922,
#           0.9922, 0.9922, 0.9804, 0.7137, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0941, 0.4471, 0.8667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.7882, 0.3059, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0902, 0.2588, 0.8353, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765,
#           0.3176, 0.0078, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.6706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.7647, 0.3137, 0.0353,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.2157, 0.6745, 0.8863, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9569, 0.5216, 0.0431, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.5333, 0.9922, 0.9922, 0.9922,
#           0.8314, 0.5294, 0.5176, 0.0627, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]]), tensor(5))
# <img src="data:image/png;base64,..." width="638.888905813665">
# Number of training examples: 60000
# Number of test examples: 10000

# %% [markdown]
# Create dataloader generator from our datasets. Dataloaders generate random samples from the training set and the test set (not randomly from the test set as it doesn't affect our results).

# %%
batch_size = 128

# dataloader is a generator that can sample from the training set
training_samples = # create the dataloader (specify batch size, )

test_samples = # create a test set data loader

# %% [markdown]
# Define a model class with the following architecture:
# - 3 convolutional layers with [128, 64, 32] channels respectively
# - append 2 fully connected (linear) layers on the end
# - use ReLU activation function between each layer
# - use dropout with probablity 0.2 of dropping out a weight after each layer

# %%
class convnet(torch.nn.Module):

    def __init__(self):
        super().__init__()
        self.conv_layers = # put your convolutional architecture here using torch.nn.Sequential 
        self.fc_layers = # put your convolutional architecture here using torch.nn.Sequential 

    def forward(self, x):
        x = # pass through conv layers
        x = # flatten output ready for fully connected layer
        x = # pass through fully connected layer
        x = # softmax activation function on outputs
        
        return x

# %% [markdown]
# Define hyper-parameters, cost function, optimizer and instantiate model

# %%
# set learning rate
# set number of epochs

cnn = #instantiate model
criterion = #use cross entropy loss function
optimizer = # use Adam optimizer, passing it the parameters of your model and the learning rate

# %% [markdown]
# Define training loop and train for the number of epochs. Since our dataset is huge and an epoch takes a while to complete, we will plot our cost every batch rather than every epoch.

# %%
def train(epochs):
    #for plotting cost per batch
    costs = []
    plt.ion()
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.show()
    ax.set_xlabel('Batch')
    ax.set_ylabel('Cost')
    
    for e in range(epochs):
        for i, (x, y) in enumerate(training_samples):
            # pass x through your model to get a prediction
            #calculate cost
            
            # zero gradients
            # calculate derivatives of values of filters (backward pass)
            # take optimiser step to update parameters

            costs.append(cost.data[0])
            ax.plot(costs, 'b')
            fig.canvas.draw()

            print('Epoch', e, '\tBatch', i, '\tCost', cost.data[0])

train(epochs)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:22: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Epoch 0 	Batch 0 	Cost tensor(2.3028)
# Epoch 0 	Batch 1 	Cost tensor(2.2985)
# Epoch 0 	Batch 2 	Cost tensor(2.2946)
# Epoch 0 	Batch 3 	Cost tensor(2.2919)
# Epoch 0 	Batch 4 	Cost tensor(2.2887)
# Epoch 0 	Batch 5 	Cost tensor(2.2811)
# Epoch 0 	Batch 6 	Cost tensor(2.2762)
# Epoch 0 	Batch 7 	Cost tensor(2.2663)
# Epoch 0 	Batch 8 	Cost tensor(2.2572)
# Epoch 0 	Batch 9 	Cost tensor(2.2484)
# Epoch 0 	Batch 10 	Cost tensor(2.2417)
# Epoch 0 	Batch 11 	Cost tensor(2.2397)
# Epoch 0 	Batch 12 	Cost tensor(2.2373)
# Epoch 0 	Batch 13 	Cost tensor(2.2044)
# Epoch 0 	Batch 14 	Cost tensor(2.2182)
# Epoch 0 	Batch 15 	Cost tensor(2.2089)
# Epoch 0 	Batch 16 	Cost tensor(2.1797)
# Epoch 0 	Batch 17 	Cost tensor(2.1559)
# Epoch 0 	Batch 18 	Cost tensor(2.1358)
# Epoch 0 	Batch 19 	Cost tensor(2.1718)
# Epoch 0 	Batch 20 	Cost tensor(2.0800)
# Epoch 0 	Batch 21 	Cost tensor(2.1034)
# Epoch 0 	Batch 22 	Cost tensor(2.0739)
# Epoch 0 	Batch 23 	Cost tensor(2.0232)
# Epoch 0 	Batch 24 	Cost tensor(2.0496)
# Epoch 0 	Batch 25 	Cost tensor(1.9856)
# Epoch 0 	Batch 26 	Cost tensor(2.0251)
# Epoch 0 	Batch 27 	Cost tensor(1.9945)
# Epoch 0 	Batch 28 	Cost tensor(1.9764)
# Epoch 0 	Batch 29 	Cost tensor(1.9831)
# Epoch 0 	Batch 30 	Cost tensor(1.9595)
# Epoch 0 	Batch 31 	Cost tensor(1.8831)
# Epoch 0 	Batch 32 	Cost tensor(1.9379)
# Epoch 0 	Batch 33 	Cost tensor(1.8974)
# Epoch 0 	Batch 34 	Cost tensor(1.8642)
# Epoch 0 	Batch 35 	Cost tensor(1.8329)
# Epoch 0 	Batch 36 	Cost tensor(1.9228)
# Epoch 0 	Batch 37 	Cost tensor(1.8494)
# Epoch 0 	Batch 38 	Cost tensor(1.8222)
# Epoch 0 	Batch 39 	Cost tensor(1.8671)
# Epoch 0 	Batch 40 	Cost tensor(1.8845)
# Epoch 0 	Batch 41 	Cost tensor(1.8641)
# Epoch 0 	Batch 42 	Cost tensor(1.7777)
# Epoch 0 	Batch 43 	Cost tensor(1.8254)
# Epoch 0 	Batch 44 	Cost tensor(1.7770)
# Epoch 0 	Batch 45 	Cost tensor(1.8005)
# Epoch 0 	Batch 46 	Cost tensor(1.7884)
# Epoch 0 	Batch 47 	Cost tensor(1.7728)
# Epoch 0 	Batch 48 	Cost tensor(1.8235)
# Epoch 0 	Batch 49 	Cost tensor(1.7392)
# Epoch 0 	Batch 50 	Cost tensor(1.8389)
# Epoch 0 	Batch 51 	Cost tensor(1.7738)
# Epoch 0 	Batch 52 	Cost tensor(1.7257)
# Epoch 0 	Batch 53 	Cost tensor(1.7282)
# Epoch 0 	Batch 54 	Cost tensor(1.7348)
# Epoch 0 	Batch 55 	Cost tensor(1.6988)
# Epoch 0 	Batch 56 	Cost tensor(1.7403)
# Epoch 0 	Batch 57 	Cost tensor(1.7251)
# Epoch 0 	Batch 58 	Cost tensor(1.7551)
# Epoch 0 	Batch 59 	Cost tensor(1.7368)
# Epoch 0 	Batch 60 	Cost tensor(1.7094)
# Epoch 0 	Batch 61 	Cost tensor(1.7492)
# Epoch 0 	Batch 62 	Cost tensor(1.7356)
# Epoch 0 	Batch 63 	Cost tensor(1.6912)
# Epoch 0 	Batch 64 	Cost tensor(1.6441)
# Epoch 0 	Batch 65 	Cost tensor(1.7166)
# Epoch 0 	Batch 66 	Cost tensor(1.6998)
# Epoch 0 	Batch 67 	Cost tensor(1.6471)
# Epoch 0 	Batch 68 	Cost tensor(1.7006)
# Epoch 0 	Batch 69 	Cost tensor(1.6681)
# Epoch 0 	Batch 70 	Cost tensor(1.6631)
# Epoch 0 	Batch 71 	Cost tensor(1.6683)
# Epoch 0 	Batch 72 	Cost tensor(1.6865)
# Epoch 0 	Batch 73 	Cost tensor(1.6633)
# Epoch 0 	Batch 74 	Cost tensor(1.6208)
# Epoch 0 	Batch 75 	Cost tensor(1.6553)
# Epoch 0 	Batch 76 	Cost tensor(1.6077)
# Epoch 0 	Batch 77 	Cost tensor(1.6458)
# Epoch 0 	Batch 78 	Cost tensor(1.6876)
# Epoch 0 	Batch 79 	Cost tensor(1.6277)
# Epoch 0 	Batch 80 	Cost tensor(1.6608)
# Epoch 0 	Batch 81 	Cost tensor(1.6131)
# Epoch 0 	Batch 82 	Cost tensor(1.6127)
# Epoch 0 	Batch 83 	Cost tensor(1.6495)
# Epoch 0 	Batch 84 	Cost tensor(1.6449)
# Epoch 0 	Batch 85 	Cost tensor(1.6005)
# Epoch 0 	Batch 86 	Cost tensor(1.6302)
# Epoch 0 	Batch 87 	Cost tensor(1.6123)
# Epoch 0 	Batch 88 	Cost tensor(1.6287)
# Epoch 0 	Batch 89 	Cost tensor(1.5804)
# Epoch 0 	Batch 90 	Cost tensor(1.6213)
# Epoch 0 	Batch 91 	Cost tensor(1.6173)
# Epoch 0 	Batch 92 	Cost tensor(1.6328)
# Epoch 0 	Batch 93 	Cost tensor(1.6410)
# Epoch 0 	Batch 94 	Cost tensor(1.6019)
# Epoch 0 	Batch 95 	Cost tensor(1.6610)
# Epoch 0 	Batch 96 	Cost tensor(1.6407)
# Epoch 0 	Batch 97 	Cost tensor(1.5752)
# Epoch 0 	Batch 98 	Cost tensor(1.6669)
# Epoch 0 	Batch 99 	Cost tensor(1.6196)
# Epoch 0 	Batch 100 	Cost tensor(1.5635)
# Epoch 0 	Batch 101 	Cost tensor(1.5990)
# Epoch 0 	Batch 102 	Cost tensor(1.6334)
# Epoch 0 	Batch 103 	Cost tensor(1.6501)
# Epoch 0 	Batch 104 	Cost tensor(1.5877)
# Epoch 0 	Batch 105 	Cost tensor(1.6630)
# Epoch 0 	Batch 106 	Cost tensor(1.6082)
# Epoch 0 	Batch 107 	Cost tensor(1.6088)
# Epoch 0 	Batch 108 	Cost tensor(1.5736)
# Epoch 0 	Batch 109 	Cost tensor(1.6048)
# Epoch 0 	Batch 110 	Cost tensor(1.6189)
# Epoch 0 	Batch 111 	Cost tensor(1.5750)
# Epoch 0 	Batch 112 	Cost tensor(1.6049)
# Epoch 0 	Batch 113 	Cost tensor(1.6246)
# Epoch 0 	Batch 114 	Cost tensor(1.6317)
# Epoch 0 	Batch 115 	Cost tensor(1.5673)
# Epoch 0 	Batch 116 	Cost tensor(1.5923)
# Epoch 0 	Batch 117 	Cost tensor(1.5749)
# Epoch 0 	Batch 118 	Cost tensor(1.5682)
# Epoch 0 	Batch 119 	Cost tensor(1.5818)
# Epoch 0 	Batch 120 	Cost tensor(1.5773)
# Epoch 0 	Batch 121 	Cost tensor(1.5470)
# Epoch 0 	Batch 122 	Cost tensor(1.5576)
# Epoch 0 	Batch 123 	Cost tensor(1.6236)
# Epoch 0 	Batch 124 	Cost tensor(1.5744)
# Epoch 0 	Batch 125 	Cost tensor(1.5621)
# Epoch 0 	Batch 126 	Cost tensor(1.5984)
# Epoch 0 	Batch 127 	Cost tensor(1.5804)
# Epoch 0 	Batch 128 	Cost tensor(1.6056)
# Epoch 0 	Batch 129 	Cost tensor(1.6083)
# Epoch 0 	Batch 130 	Cost tensor(1.5473)
# Epoch 0 	Batch 131 	Cost tensor(1.6234)
# Epoch 0 	Batch 132 	Cost tensor(1.6098)
# Epoch 0 	Batch 133 	Cost tensor(1.6001)
# Epoch 0 	Batch 134 	Cost tensor(1.6086)
# Epoch 0 	Batch 135 	Cost tensor(1.5863)
# Epoch 0 	Batch 136 	Cost tensor(1.5945)
# Epoch 0 	Batch 137 	Cost tensor(1.5919)
# Epoch 0 	Batch 138 	Cost tensor(1.5824)
# Epoch 0 	Batch 139 	Cost tensor(1.5697)
# Epoch 0 	Batch 140 	Cost tensor(1.5439)
# Epoch 0 	Batch 141 	Cost tensor(1.5877)
# Epoch 0 	Batch 142 	Cost tensor(1.5979)
# Epoch 0 	Batch 143 	Cost tensor(1.5973)
# Epoch 0 	Batch 144 	Cost tensor(1.5404)
# Epoch 0 	Batch 145 	Cost tensor(1.5759)
# Epoch 0 	Batch 146 	Cost tensor(1.5691)
# Epoch 0 	Batch 147 	Cost tensor(1.6049)
# Epoch 0 	Batch 148 	Cost tensor(1.5828)
# Epoch 0 	Batch 149 	Cost tensor(1.5993)
# Epoch 0 	Batch 150 	Cost tensor(1.6116)
# Epoch 0 	Batch 151 	Cost tensor(1.5538)
# Epoch 0 	Batch 152 	Cost tensor(1.5701)
# Epoch 0 	Batch 153 	Cost tensor(1.5948)
# Epoch 0 	Batch 154 	Cost tensor(1.5969)
# Epoch 0 	Batch 155 	Cost tensor(1.5534)
# Epoch 0 	Batch 156 	Cost tensor(1.5628)
# Epoch 0 	Batch 157 	Cost tensor(1.5836)
# Epoch 0 	Batch 158 	Cost tensor(1.5696)
# Epoch 0 	Batch 159 	Cost tensor(1.5921)
# Epoch 0 	Batch 160 	Cost tensor(1.5596)
# Epoch 0 	Batch 161 	Cost tensor(1.5317)
# Epoch 0 	Batch 162 	Cost tensor(1.5432)
# Epoch 0 	Batch 163 	Cost tensor(1.5965)
# Epoch 0 	Batch 164 	Cost tensor(1.5777)
# Epoch 0 	Batch 165 	Cost tensor(1.5639)
# Epoch 0 	Batch 166 	Cost tensor(1.5912)
# Epoch 0 	Batch 167 	Cost tensor(1.5862)
# Epoch 0 	Batch 168 	Cost tensor(1.5764)
# Epoch 0 	Batch 169 	Cost tensor(1.6091)
# Epoch 0 	Batch 170 	Cost tensor(1.5972)
# Epoch 0 	Batch 171 	Cost tensor(1.5792)
# Epoch 0 	Batch 172 	Cost tensor(1.5864)
# Epoch 0 	Batch 173 	Cost tensor(1.6041)
# Epoch 0 	Batch 174 	Cost tensor(1.5711)
# Epoch 0 	Batch 175 	Cost tensor(1.6029)
# Epoch 0 	Batch 176 	Cost tensor(1.5746)
# Epoch 0 	Batch 177 	Cost tensor(1.5946)
# Epoch 0 	Batch 178 	Cost tensor(1.5824)
# Epoch 0 	Batch 179 	Cost tensor(1.5627)
# Epoch 0 	Batch 180 	Cost tensor(1.5571)
# Epoch 0 	Batch 181 	Cost tensor(1.5941)
# Epoch 0 	Batch 182 	Cost tensor(1.5195)
# Epoch 0 	Batch 183 	Cost tensor(1.5908)
# Epoch 0 	Batch 184 	Cost tensor(1.5571)
# Epoch 0 	Batch 185 	Cost tensor(1.5920)
# Epoch 0 	Batch 186 	Cost tensor(1.6056)
# Epoch 0 	Batch 187 	Cost tensor(1.5802)
# Epoch 0 	Batch 188 	Cost tensor(1.5393)
# Epoch 0 	Batch 189 	Cost tensor(1.5871)
# Epoch 0 	Batch 190 	Cost tensor(1.6059)
# Epoch 0 	Batch 191 	Cost tensor(1.5626)
# Epoch 0 	Batch 192 	Cost tensor(1.5675)
# Epoch 0 	Batch 193 	Cost tensor(1.5603)
# Epoch 0 	Batch 194 	Cost tensor(1.5628)
# Epoch 0 	Batch 195 	Cost tensor(1.5618)
# Epoch 0 	Batch 196 	Cost tensor(1.5967)
# Epoch 0 	Batch 197 	Cost tensor(1.5494)
# Epoch 0 	Batch 198 	Cost tensor(1.5377)
# Epoch 0 	Batch 199 	Cost tensor(1.5533)
# Epoch 0 	Batch 200 	Cost tensor(1.5455)
# Epoch 0 	Batch 201 	Cost tensor(1.5781)
# Epoch 0 	Batch 202 	Cost tensor(1.5488)
# Epoch 0 	Batch 203 	Cost tensor(1.5505)
# Epoch 0 	Batch 204 	Cost tensor(1.5613)
# Epoch 0 	Batch 205 	Cost tensor(1.5202)
# Epoch 0 	Batch 206 	Cost tensor(1.5618)
# Epoch 0 	Batch 207 	Cost tensor(1.5451)
# Epoch 0 	Batch 208 	Cost tensor(1.5764)
# Epoch 0 	Batch 209 	Cost tensor(1.5401)
# Epoch 0 	Batch 210 	Cost tensor(1.5796)
# Epoch 0 	Batch 211 	Cost tensor(1.5679)
# Epoch 0 	Batch 212 	Cost tensor(1.5231)
# Epoch 0 	Batch 213 	Cost tensor(1.5487)
# Epoch 0 	Batch 214 	Cost tensor(1.5566)
# Epoch 0 	Batch 215 	Cost tensor(1.5324)
# Epoch 0 	Batch 216 	Cost tensor(1.5496)
# Epoch 0 	Batch 217 	Cost tensor(1.5561)
# Epoch 0 	Batch 218 	Cost tensor(1.5707)
# Epoch 0 	Batch 219 	Cost tensor(1.5448)
# Epoch 0 	Batch 220 	Cost tensor(1.5443)
# Epoch 0 	Batch 221 	Cost tensor(1.5223)
# Epoch 0 	Batch 222 	Cost tensor(1.5576)
# Epoch 0 	Batch 223 	Cost tensor(1.5582)
# Epoch 0 	Batch 224 	Cost tensor(1.5888)
# Epoch 0 	Batch 225 	Cost tensor(1.5444)
# Epoch 0 	Batch 226 	Cost tensor(1.5412)
# Epoch 0 	Batch 227 	Cost tensor(1.6056)
# Epoch 0 	Batch 228 	Cost tensor(1.5787)
# Epoch 0 	Batch 229 	Cost tensor(1.5650)
# Epoch 0 	Batch 230 	Cost tensor(1.5379)
# Epoch 0 	Batch 231 	Cost tensor(1.5248)
# Epoch 0 	Batch 232 	Cost tensor(1.6109)
# Epoch 0 	Batch 233 	Cost tensor(1.5450)
# Epoch 0 	Batch 234 	Cost tensor(1.5491)
# Epoch 0 	Batch 235 	Cost tensor(1.5569)
# Epoch 0 	Batch 236 	Cost tensor(1.5162)
# Epoch 0 	Batch 237 	Cost tensor(1.5318)
# Epoch 0 	Batch 238 	Cost tensor(1.5357)
# Epoch 0 	Batch 239 	Cost tensor(1.5589)
# Epoch 0 	Batch 240 	Cost tensor(1.5761)
# Epoch 0 	Batch 241 	Cost tensor(1.5936)
# Epoch 0 	Batch 242 	Cost tensor(1.5650)
# Epoch 0 	Batch 243 	Cost tensor(1.5641)
# Epoch 0 	Batch 244 	Cost tensor(1.5717)
# Epoch 0 	Batch 245 	Cost tensor(1.5283)
# Epoch 0 	Batch 246 	Cost tensor(1.5522)
# Epoch 0 	Batch 247 	Cost tensor(1.5697)
# Epoch 0 	Batch 248 	Cost tensor(1.5314)
# Epoch 0 	Batch 249 	Cost tensor(1.5659)
# Epoch 0 	Batch 250 	Cost tensor(1.5318)
# Epoch 0 	Batch 251 	Cost tensor(1.5639)
# Epoch 0 	Batch 252 	Cost tensor(1.5914)
# Epoch 0 	Batch 253 	Cost tensor(1.5741)
# Epoch 0 	Batch 254 	Cost tensor(1.5449)
# Epoch 0 	Batch 255 	Cost tensor(1.5365)
# Epoch 0 	Batch 256 	Cost tensor(1.6001)
# Epoch 0 	Batch 257 	Cost tensor(1.5864)
# Epoch 0 	Batch 258 	Cost tensor(1.5341)
# Epoch 0 	Batch 259 	Cost tensor(1.5328)
# Epoch 0 	Batch 260 	Cost tensor(1.5322)
# Epoch 0 	Batch 261 	Cost tensor(1.5882)
# Epoch 0 	Batch 262 	Cost tensor(1.5896)
# Epoch 0 	Batch 263 	Cost tensor(1.5532)
# Epoch 0 	Batch 264 	Cost tensor(1.5416)
# Epoch 0 	Batch 265 	Cost tensor(1.5194)
# Epoch 0 	Batch 266 	Cost tensor(1.5094)
# Epoch 0 	Batch 267 	Cost tensor(1.5367)
# Epoch 0 	Batch 268 	Cost tensor(1.5630)
# Epoch 0 	Batch 269 	Cost tensor(1.5342)
# Epoch 0 	Batch 270 	Cost tensor(1.5269)
# Epoch 0 	Batch 271 	Cost tensor(1.5096)
# Epoch 0 	Batch 272 	Cost tensor(1.5822)
# Epoch 0 	Batch 273 	Cost tensor(1.5202)
# Epoch 0 	Batch 274 	Cost tensor(1.5118)
# Epoch 0 	Batch 275 	Cost tensor(1.5565)
# Epoch 0 	Batch 276 	Cost tensor(1.5540)
# Epoch 0 	Batch 277 	Cost tensor(1.5798)
# Epoch 0 	Batch 278 	Cost tensor(1.5359)
# Epoch 0 	Batch 279 	Cost tensor(1.6076)
# Epoch 0 	Batch 280 	Cost tensor(1.5789)
# Epoch 0 	Batch 281 	Cost tensor(1.5566)
# Epoch 0 	Batch 282 	Cost tensor(1.5490)
# Epoch 0 	Batch 283 	Cost tensor(1.5701)
# Epoch 0 	Batch 284 	Cost tensor(1.5703)
# Epoch 0 	Batch 285 	Cost tensor(1.5366)
# Epoch 0 	Batch 286 	Cost tensor(1.5519)
# Epoch 0 	Batch 287 	Cost tensor(1.5971)
# Epoch 0 	Batch 288 	Cost tensor(1.5358)
# Epoch 0 	Batch 289 	Cost tensor(1.5612)
# Epoch 0 	Batch 290 	Cost tensor(1.5425)
# Epoch 0 	Batch 291 	Cost tensor(1.5636)
# Epoch 0 	Batch 292 	Cost tensor(1.5381)
# Epoch 0 	Batch 293 	Cost tensor(1.6174)
# Epoch 0 	Batch 294 	Cost tensor(1.5255)
# Epoch 0 	Batch 295 	Cost tensor(1.5680)
# Epoch 0 	Batch 296 	Cost tensor(1.5528)
# Epoch 0 	Batch 297 	Cost tensor(1.5539)
# Epoch 0 	Batch 298 	Cost tensor(1.5331)
# Epoch 0 	Batch 299 	Cost tensor(1.5184)
# Epoch 0 	Batch 300 	Cost tensor(1.5471)
# Epoch 0 	Batch 301 	Cost tensor(1.5523)
# Epoch 0 	Batch 302 	Cost tensor(1.5446)
# Epoch 0 	Batch 303 	Cost tensor(1.5398)
# Epoch 0 	Batch 304 	Cost tensor(1.5340)
# Epoch 0 	Batch 305 	Cost tensor(1.5579)
# Epoch 0 	Batch 306 	Cost tensor(1.5359)
# Epoch 0 	Batch 307 	Cost tensor(1.5329)
# Epoch 0 	Batch 308 	Cost tensor(1.5085)
# Epoch 0 	Batch 309 	Cost tensor(1.5843)
# Epoch 0 	Batch 310 	Cost tensor(1.5758)
# Epoch 0 	Batch 311 	Cost tensor(1.5063)
# Epoch 0 	Batch 312 	Cost tensor(1.5583)
# Epoch 0 	Batch 313 	Cost tensor(1.5451)
# Epoch 0 	Batch 314 	Cost tensor(1.5368)
# Epoch 0 	Batch 315 	Cost tensor(1.5597)
# Epoch 0 	Batch 316 	Cost tensor(1.5792)
# Epoch 0 	Batch 317 	Cost tensor(1.5345)
# Epoch 0 	Batch 318 	Cost tensor(1.5576)
# Epoch 0 	Batch 319 	Cost tensor(1.5367)
# Epoch 0 	Batch 320 	Cost tensor(1.5446)
# Epoch 0 	Batch 321 	Cost tensor(1.5880)
# Epoch 0 	Batch 322 	Cost tensor(1.5378)
# Epoch 0 	Batch 323 	Cost tensor(1.5292)
# Epoch 0 	Batch 324 	Cost tensor(1.5408)
# Epoch 0 	Batch 325 	Cost tensor(1.5166)
# Epoch 0 	Batch 326 	Cost tensor(1.5101)
# Epoch 0 	Batch 327 	Cost tensor(1.5517)
# Epoch 0 	Batch 328 	Cost tensor(1.5394)
# Epoch 0 	Batch 329 	Cost tensor(1.5477)
# Epoch 0 	Batch 330 	Cost tensor(1.5724)
# Epoch 0 	Batch 331 	Cost tensor(1.5642)
# Epoch 0 	Batch 332 	Cost tensor(1.5204)
# Epoch 0 	Batch 333 	Cost tensor(1.5638)
# Epoch 0 	Batch 334 	Cost tensor(1.5355)
# Epoch 0 	Batch 335 	Cost tensor(1.5623)
# Epoch 0 	Batch 336 	Cost tensor(1.5382)
# Epoch 0 	Batch 337 	Cost tensor(1.5701)
# Epoch 0 	Batch 338 	Cost tensor(1.5514)
# Epoch 0 	Batch 339 	Cost tensor(1.5440)
# Epoch 0 	Batch 340 	Cost tensor(1.5487)
# Epoch 0 	Batch 341 	Cost tensor(1.5271)
# Epoch 0 	Batch 342 	Cost tensor(1.5608)
# Epoch 0 	Batch 343 	Cost tensor(1.5716)
# Epoch 0 	Batch 344 	Cost tensor(1.5370)
# Epoch 0 	Batch 345 	Cost tensor(1.5406)
# Epoch 0 	Batch 346 	Cost tensor(1.5508)
# Epoch 0 	Batch 347 	Cost tensor(1.5284)
# Epoch 0 	Batch 348 	Cost tensor(1.5299)
# Epoch 0 	Batch 349 	Cost tensor(1.5482)
# Epoch 0 	Batch 350 	Cost tensor(1.5657)
# Epoch 0 	Batch 351 	Cost tensor(1.5170)
# Epoch 0 	Batch 352 	Cost tensor(1.5306)
# Epoch 0 	Batch 353 	Cost tensor(1.5173)
# Epoch 0 	Batch 354 	Cost tensor(1.5518)
# Epoch 0 	Batch 355 	Cost tensor(1.5283)
# Epoch 0 	Batch 356 	Cost tensor(1.5428)
# Epoch 0 	Batch 357 	Cost tensor(1.5619)
# Epoch 0 	Batch 358 	Cost tensor(1.5502)
# Epoch 0 	Batch 359 	Cost tensor(1.5758)
# Epoch 0 	Batch 360 	Cost tensor(1.5431)
# Epoch 0 	Batch 361 	Cost tensor(1.5625)
# Epoch 0 	Batch 362 	Cost tensor(1.5658)
# Epoch 0 	Batch 363 	Cost tensor(1.5568)
# Epoch 0 	Batch 364 	Cost tensor(1.5268)
# Epoch 0 	Batch 365 	Cost tensor(1.5688)
# Epoch 0 	Batch 366 	Cost tensor(1.5176)
# Epoch 0 	Batch 367 	Cost tensor(1.5480)
# Epoch 0 	Batch 368 	Cost tensor(1.5668)
# Epoch 0 	Batch 369 	Cost tensor(1.5969)
# Epoch 0 	Batch 370 	Cost tensor(1.5606)
# Epoch 0 	Batch 371 	Cost tensor(1.5342)
# Epoch 0 	Batch 372 	Cost tensor(1.5316)
# Epoch 0 	Batch 373 	Cost tensor(1.5433)
# Epoch 0 	Batch 374 	Cost tensor(1.5572)
# Epoch 0 	Batch 375 	Cost tensor(1.5826)
# Epoch 0 	Batch 376 	Cost tensor(1.5361)
# Epoch 0 	Batch 377 	Cost tensor(1.5569)
# Epoch 0 	Batch 378 	Cost tensor(1.5331)
# Epoch 0 	Batch 379 	Cost tensor(1.5676)
# Epoch 0 	Batch 380 	Cost tensor(1.5406)
# Epoch 0 	Batch 381 	Cost tensor(1.5613)
# Epoch 0 	Batch 382 	Cost tensor(1.5473)
# Epoch 0 	Batch 383 	Cost tensor(1.5603)
# Epoch 0 	Batch 384 	Cost tensor(1.5306)
# Epoch 0 	Batch 385 	Cost tensor(1.5334)
# Epoch 0 	Batch 386 	Cost tensor(1.5675)
# Epoch 0 	Batch 387 	Cost tensor(1.5518)
# Epoch 0 	Batch 388 	Cost tensor(1.5298)
# Epoch 0 	Batch 389 	Cost tensor(1.5607)
# Epoch 0 	Batch 390 	Cost tensor(1.5403)
# Epoch 0 	Batch 391 	Cost tensor(1.5709)
# Epoch 0 	Batch 392 	Cost tensor(1.5282)
# Epoch 0 	Batch 393 	Cost tensor(1.5089)
# Epoch 0 	Batch 394 	Cost tensor(1.5339)
# Epoch 0 	Batch 395 	Cost tensor(1.5407)
# Epoch 0 	Batch 396 	Cost tensor(1.5684)
# Epoch 0 	Batch 397 	Cost tensor(1.5326)
# Epoch 0 	Batch 398 	Cost tensor(1.5574)
# Epoch 0 	Batch 399 	Cost tensor(1.5423)
# Epoch 0 	Batch 400 	Cost tensor(1.5330)
# Epoch 0 	Batch 401 	Cost tensor(1.5698)
# Epoch 0 	Batch 402 	Cost tensor(1.5444)
# Epoch 0 	Batch 403 	Cost tensor(1.5468)
# Epoch 0 	Batch 404 	Cost tensor(1.5149)
# Epoch 0 	Batch 405 	Cost tensor(1.5158)
# Epoch 0 	Batch 406 	Cost tensor(1.5845)
# Epoch 0 	Batch 407 	Cost tensor(1.5497)
# Epoch 0 	Batch 408 	Cost tensor(1.5196)
# Epoch 0 	Batch 409 	Cost tensor(1.4954)
# Epoch 0 	Batch 410 	Cost tensor(1.5225)

# %% [markdown]
# Test our model on the test set

# %%
def test():
    print('Started evaluation...')
    cnn.eval() #put model into evaluation mode
    
    #calculate the accuracy of our model over the whole test set in batches
    correct = 0
    for x, y in test_samples:
        x, y = Variable(x), y
        h = cnn.forward(x)
        pred = h.data.max(1)[1]
        correct += pred.eq(y).sum()
    return correct/len(test_data)

acc = test()
print('Test accuracy: ', acc)
