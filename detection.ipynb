# %% [markdown]
# # Building a CNN for object detection

# %%
# IMPORTS
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
import S40dataset
import matplotlib.pyplot as plt
import time

# %%
# HYPERPARAMETERS
batch_size = 4
epochs = 1
lr = 0.00001

# %%
transform = transforms.Compose([# compose transforms 
    transforms.Resize((64, 64)),# resize imgs
    transforms.ToTensor()# convert PIL images into Torch Tensors
])


# MAKE DATASET
dataset = S40dataset.S40dataset(transform=transform)# make the dataset and pass it our transforms

# SPLIT DATASET
train_len = int( 0.8 * len(dataset))
val_len = int( 0.1 * len(dataset))
test_len = len(dataset) - train_len - val_len
train_data, val_data, test_data = random_split(dataset, [train_len, val_len, test_len])# split the dataset into train, test, validation

# MAKE DATALOADERS
train_loader = DataLoader(train_data,# make the training dataloader
                          batch_size = batch_size,
                          shuffle=True)
test_loader = DataLoader(test_data,
                       batch_size=batch_size)

# SHOW A RANDOM EXAMPLE FROM THE DATASET
for i in test_loader:
    b = i
    
    break
import numpy as np
idx = np.random.randint(len(test_loader))
S40dataset.show(b)
# Out:
# ['images/applauding_001.jpg', 'images/applauding_002.jpg', 'images/applauding_003.jpg', 'images/applauding_004.jpg', 'images/applauding_005.jpg', 'images/applauding_006.jpg', 'images/applauding_007.jpg', 'images/applauding_008.jpg', 'images/applauding_009.jpg', 'images/applauding_010.jpg', 'images/applauding_011.jpg', 'images/applauding_012.jpg', 'images/applauding_013.jpg', 'images/applauding_014.jpg', 'images/applauding_015.jpg', 'images/applauding_016.jpg', 'images/applauding_017.jpg', 'images/applauding_018.jpg', 'images/applauding_019.jpg', 'images/applauding_020.jpg', 'images/applauding_021.jpg', 'images/applauding_022.jpg', 'images/applauding_023.jpg', 'images/applauding_024.jpg', 'images/applauding_025.jpg', 'images/applauding_026.jpg', 'images/applauding_027.jpg', 'images/applauding_028.jpg', 'images/applauding_029.jpg', 'images/applauding_030.jpg', 'images/applauding_031.jpg', 'images/applauding_032.jpg', 'images/applauding_033.jpg', 'images/applauding_034.jpg', 'images/applauding_035.jpg', 'images/applauding_036.jpg', 'images/applauding_037.jpg', 'images/applauding_038.jpg', 'images/applauding_039.jpg', 'images/applauding_040.jpg', 'images/applauding_041.jpg', 'images/applauding_042.jpg', 'images/applauding_043.jpg', 'images/applauding_044.jpg', 'images/applauding_045.jpg', 'images/applauding_046.jpg', 'images/applauding_047.jpg', 'images/applauding_048.jpg', 'images/applauding_049.jpg', 'images/applauding_050.jpg', 'images/applauding_051.jpg', 'images/applauding_052.jpg', 'images/applauding_053.jpg', 'images/applauding_054.jpg', 'images/applauding_055.jpg', 'images/applauding_056.jpg', 'images/applauding_057.jpg', 'images/applauding_058.jpg', 'images/applauding_059.jpg', 'images/applauding_060.jpg', 'images/applauding_061.jpg', 'images/applauding_062.jpg', 'images/applauding_063.jpg', 'images/applauding_064.jpg', 'images/applauding_065.jpg', 'images/applauding_066.jpg', 'images/applauding_067.jpg', 'images/applauding_068.jpg', 'images/applauding_069.jpg', 'images/applauding_070.jpg', 'images/applauding_071.jpg', 'images/applauding_072.jpg', 'images/applauding_073.jpg', 'images/applauding_074.jpg', 'images/applauding_075.jpg', 'images/applauding_076.jpg', 'images/applauding_077.jpg', 'images/applauding_078.jpg', 'images/applauding_079.jpg', 'images/applauding_080.jpg', 'images/applauding_081.jpg', 'images/applauding_082.jpg', 'images/applauding_083.jpg', 'images/applauding_084.jpg', 'images/applauding_085.jpg', 'images/applauding_086.jpg', 'images/applauding_087.jpg', 'images/applauding_088.jpg', 'images/applauding_089.jpg', 'images/applauding_090.jpg', 'images/applauding_091.jpg', 'images/applauding_092.jpg', 'images/applauding_093.jpg', 'images/applauding_094.jpg', 'images/applauding_095.jpg', 'images/applauding_096.jpg', 'images/applauding_097.jpg', 'images/applauding_098.jpg', 'images/applauding_099.jpg', 'images/applauding_100.jpg', 'images/applauding_101.jpg', 'images/applauding_102.jpg', 'images/applauding_103.jpg', 'images/applauding_104.jpg', 'images/applauding_105.jpg', 'images/applauding_106.jpg', 'images/applauding_107.jpg', 'images/applauding_108.jpg', 'images/applauding_109.jpg', 'images/applauding_110.jpg', 'images/applauding_111.jpg', 'images/applauding_112.jpg', 'images/applauding_113.jpg', 'images/applauding_114.jpg', 'images/applauding_115.jpg', 'images/applauding_116.jpg', 'images/applauding_117.jpg', 'images/applauding_118.jpg', 'images/applauding_119.jpg', 'images/applauding_120.jpg', 'images/applauding_121.jpg', 'images/applauding_122.jpg', 'images/applauding_123.jpg', 'images/applauding_124.jpg', 'images/applauding_125.jpg', 'images/applauding_126.jpg', 'images/applauding_127.jpg', 'images/applauding_128.jpg', 'images/applauding_129.jpg', 'images/applauding_130.jpg', 'images/applauding_131.jpg', 'images/applauding_132.jpg', 'images/applauding_133.jpg', 'images/applauding_134.jpg', 'images/applauding_135.jpg', 'images/applauding_136.jpg', 'images/applauding_137.jpg', 'images/applauding_138.jpg ...
# ['annotations/applauding_001.xml', 'annotations/applauding_002.xml', 'annotations/applauding_003.xml', 'annotations/applauding_004.xml', 'annotations/applauding_005.xml', 'annotations/applauding_006.xml', 'annotations/applauding_007.xml', 'annotations/applauding_008.xml', 'annotations/applauding_009.xml', 'annotations/applauding_010.xml', 'annotations/applauding_011.xml', 'annotations/applauding_012.xml', 'annotations/applauding_013.xml', 'annotations/applauding_014.xml', 'annotations/applauding_015.xml', 'annotations/applauding_016.xml', 'annotations/applauding_017.xml', 'annotations/applauding_018.xml', 'annotations/applauding_019.xml', 'annotations/applauding_020.xml', 'annotations/applauding_021.xml', 'annotations/applauding_022.xml', 'annotations/applauding_023.xml', 'annotations/applauding_024.xml', 'annotations/applauding_025.xml', 'annotations/applauding_026.xml', 'annotations/applauding_027.xml', 'annotations/applauding_028.xml', 'annotations/applauding_029.xml', 'annotations/applauding_030.xml', 'annotations/applauding_031.xml', 'annotations/applauding_032.xml', 'annotations/applauding_033.xml', 'annotations/applauding_034.xml', 'annotations/applauding_035.xml', 'annotations/applauding_036.xml', 'annotations/applauding_037.xml', 'annotations/applauding_038.xml', 'annotations/applauding_039.xml', 'annotations/applauding_040.xml', 'annotations/applauding_041.xml', 'annotations/applauding_042.xml', 'annotations/applauding_043.xml', 'annotations/applauding_044.xml', 'annotations/applauding_045.xml', 'annotations/applauding_046.xml', 'annotations/applauding_047.xml', 'annotations/applauding_048.xml', 'annotations/applauding_049.xml', 'annotations/applauding_050.xml', 'annotations/applauding_051.xml', 'annotations/applauding_052.xml', 'annotations/applauding_053.xml', 'annotations/applauding_054.xml', 'annotations/applauding_055.xml', 'annotations/applauding_056.xml', 'annotations/applauding_057.xml', 'annotations/applauding_058.xml', 'annotations/applauding_059.xml', 'annotations/applauding_060.xml', 'annotations/applauding_061.xml', 'annotations/applauding_062.xml', 'annotations/applauding_063.xml', 'annotations/applauding_064.xml', 'annotations/applauding_065.xml', 'annotations/applauding_066.xml', 'annotations/applauding_067.xml', 'annotations/applauding_068.xml', 'annotations/applauding_069.xml', 'annotations/applauding_070.xml', 'annotations/applauding_071.xml', 'annotations/applauding_072.xml', 'annotations/applauding_073.xml', 'annotations/applauding_074.xml', 'annotations/applauding_075.xml', 'annotations/applauding_076.xml', 'annotations/applauding_077.xml', 'annotations/applauding_078.xml', 'annotations/applauding_079.xml', 'annotations/applauding_080.xml', 'annotations/applauding_081.xml', 'annotations/applauding_082.xml', 'annotations/applauding_083.xml', 'annotations/applauding_084.xml', 'annotations/applauding_085.xml', 'annotations/applauding_086.xml', 'annotations/applauding_087.xml', 'annotations/applauding_088.xml', 'annotations/applauding_089.xml', 'annotations/applauding_090.xml', 'annotations/applauding_091.xml', 'annotations/applauding_092.xml', 'annotations/applauding_093.xml', 'annotations/applauding_094.xml', 'annotations/applauding_095.xml', 'annotations/applauding_096.xml', 'annotations/applauding_097.xml', 'annotations/applauding_098.xml', 'annotations/applauding_099.xml', 'annotations/applauding_100.xml', 'annotations/applauding_101.xml', 'annotations/applauding_102.xml', 'annotations/applauding_103.xml', 'annotations/applauding_104.xml', 'annotations/applauding_105.xml', 'annotations/applauding_106.xml', 'annotations/applauding_107.xml', 'annotations/applauding_108.xml', 'annotations/applauding_109.xml', 'annotations/applauding_110.xml', 'annotations/applauding_111.xml', 'annotations/applauding_112.xml', 'annotations/applauding_113.xml', 'annotations/applauding_114.xml', 'annotations/applauding_115.xml', 'annotations/applauding_116.xml', 'annotations/applauding_117.xml', 'annotations/applaudi ...
# images/feeding_a_horse_123.jpg
# images/blowing_bubbles_050.jpg
# images/blowing_bubbles_249.jpg
# images/fixing_a_car_201.jpg
# torch.Size([3, 64, 64])
# [tensor(22.1867), tensor(145.9200), tensor(244.0533), tensor(440.3200)]
# [tensor(22.1867), tensor(145.9200), tensor(244.0533), tensor(440.3200)]

# %%
# SET NUMBER OF FILTERS TO USE IN EACH CONV LAYER
channels1 = 128
channels2 = 64
channels3 = 64
channels4 = 64

# CREATE MODEL
class DetectCNN(torch.nn.Module):# create class
    def __init__(self):# initialise
        super().__init__()         # initialise parent class
        self.conv_layers = torch.nn.Sequential(        # make sequential model for conv layers
            torch.nn.Conv2d(3, channels1, 7),            # make layers
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(channels1),
            torch.nn.Dropout(0.2),
            torch.nn.Conv2d(channels1, channels2, 7),            # make layers
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(channels2),
            torch.nn.Dropout(0.2),
            torch.nn.Conv2d(channels2, channels3, 7),            # make layers
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(channels3),
            torch.nn.Dropout(0.2),
        )
        self.fc_layers = torch.nn.Sequential(# make sequential model for fully connected (linear) layers
            torch.nn.Linear(64*46*46, 4),# make layers
            torch.nn.Sigmoid()
        )
    
    def forward(self, x):# define forward pass
        x = self.conv_layers(x)# forward pass through conv layers
        print(x.shape)
        x = x.view(-1, 64*46*46)# flatten conv output to pass to fully connected layers
        x = self.fc_layers(x)# pass through fc layers
        return x# return output
        
cnn = DetectCNN()# create instance of model
criterion = torch.nn.MSELoss()# define loss function
optimiser = torch.optim.Adam(cnn.parameters(), lr=lr, weight_decay=1)# define optimiser

# TRAIN
def train(model):

    train_losses = []
    for epoch in range(epochs):
        for batch_idx, batch in enumerate(train_loader):
            x, bndbox = batch    # unpack batch
            pred_bndbox = model(x)# forward pass
            #print('label:', bndbox, 'prediction:', pred_bndbox)
            loss = criterion(pred_bndbox, bndbox)     # compute loss for this batch
            optimiser.zero_grad()# zero gradients of optimiser
            loss.backward()     # backward pass (find rate of change of loss with respect to model parameters)
            optimiser.step()# take optimisation step
            print('Epoch:', epoch, 'Batch:', batch_idx, 'Loss:', loss.item())
            train_losses.append(loss.item())    #append loss for this batch to list of all losses
            if batch_idx == 200:    # tell your model to stop at some batch_idx if you want
                #break
                pass
            
    return train_losses

train_losses = train(cnn)
torch.save(cnn.state_dict(), str(time.time()))# save model

plt.plot(train_losses)
plt.show()
# Out:
# images/waving_hands_125.jpg
# images/washing_dishes_172.jpg
# images/gardening_057.jpg
# images/pushing_a_cart_080.jpg
# torch.Size([4, 64, 46, 46])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-71fb92cb7476> in <module>
#      61     return train_losses
#      62
# ---> 63 train_losses = train(cnn)
#      64 torch.save(cnn.state_dict(), str(time.time()))# save model
#      65
#
# <ipython-input-10-71fb92cb7476> in train(model)
#      51             loss = criterion(pred_bndbox, bndbox)     # compute loss for this batch
#      52             optimiser.zero_grad()# zero gradients of optimiser
# ---> 53             loss.backward()     # backward pass (find rate of change of loss with respect to model parameters)
#      54             optimiser.step()# take optimisation step
#      55             print('Epoch:', epoch, 'Batch:', batch_idx, 'Loss:', loss.item())
#
# ~/.local/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/.local/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
def test(model):
    # set in evaluation mode
    for idx, batch in enumerate(test_loader):
        print(type(batch))
        # unpack batch
        # forward pass
        S40dataset.show(batch, pred_bndbox=pred_bndbox)
        if idx == 10:
            break


test(cnn)
